# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Import data

# %%
path_bike_sharing_days = "../datasets/bike-sharing/day.csv"
path_bike_sharing_hours = "../datasets/bike-sharing/hour.csv"
path_bike_sharing_days_seoul = "../datasets/bike-sharing-seoul/SeoulBikeData.csv"
path_absenteeism_work = "../datasets/absenteeism-at-work/Absenteeism_at_work.csv"

# %%
bike_sharing_days = pd.read_csv(path_bike_sharing_days)
bike_sharing_hours = pd.read_csv(path_bike_sharing_hours)
bike_sharing_days_seoul = pd.read_csv(path_bike_sharing_days_seoul)
absenteeism_work = pd.read_csv(path_absenteeism_work, delimiter=";")

# %%
bike_sharing_days
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
bike_sharing_days_seoul
# Out:
#             Date  Rented Bike Count  Hour  Temperature(C)  Humidity(%)  \
# 0     01/12/2017                254     0            -5.2           37
# 1     01/12/2017                204     1            -5.5           38
# 2     01/12/2017                173     2            -6.0           39
# 3     01/12/2017                107     3            -6.2           40
# 4     01/12/2017                 78     4            -6.0           36
# ...          ...                ...   ...             ...          ...
# 8755  30/11/2018               1003    19             4.2           34
# 8756  30/11/2018                764    20             3.4           37
# 8757  30/11/2018                694    21             2.6           39
# 8758  30/11/2018                712    22             2.1           41
# 8759  30/11/2018                584    23             1.9           43
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(C)  \
# ...

# %%
plt.plot(bike_sharing_days["cnt"])

# %%
plt.plot(bike_sharing_days["temp"])

# %%
absenteeism_work
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# ..   ..                 ...               ...              ...      ...
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %%
import matplotlib.pyplot as plt

# Your category mapping dictionary
category_mapping = {
    1: "Infectious and parasitic",
    2: "Neoplasms",
    3: "Blood and blood-forming organ",
    4: "Endocrine, nutritional and metabolic",
    5: "Mental and behavioural disorders",
    6: "Nervous system",
    7: "Eye and adnexa",
    8: "Ear and mastoid process",
    9: "Circulatory system",
    10: "Respiratory system",
    11: "Digestive system",
    12: "Skin and subcutaneous tissue",
    13: "Musculoskeletal system",
    14: "Genitourinary system",
    15: "Pregnancy, childbirth and puerperium",
    16: "Perinatal period conditions",
    17: "Congenital malformations, deformations",
    18: "Abnormal clinical symptoms",
    19: "Injury, poisoning",
    20: "Morbidity and mortality ",
    21: "Health service encounters",
    22: "Patient follow-up",
    23: "Medical consultation",
    24: "Blood donation",
    25: "Laboratory examination",
    26: "Unjustified absence",
    27: "Physiotherapy",
    28: "Dental consultation"
}
# Create the histogram
plt.hist(absenteeism_work["Reason for absence"], bins=range(1, 30), align='left', rwidth=0.8)

# Set the title and labels for axes
plt.title("Distribution of Absence Reason Categories")
plt.xlabel("Absence/Disease Category")
plt.ylabel("Number of Occurrences")

# Set the xticks labels based on the category_mapping
plt.xticks(list(category_mapping.keys()), list(category_mapping.values()), rotation=90)

# Show the plot
plt.show()
